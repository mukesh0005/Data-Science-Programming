# %% [markdown]
# # Predictive Modeling Example

# %% [markdown]
# ## Step 1: Import the libraries we will use in this notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

np.random.seed(1) # set this to ensure the results are repeatable.

# %% [markdown]
# ## Step 2: Load the given data that we will model

# %%
df = pd.read_csv('./data/c02_dataset_3_obs.csv')

df.head(3)
# Out:
#    input     target
# 0  16.24  -4.072333
# 1  -6.12  25.245091
# 2  -5.28  41.717226

# %% [markdown]
# Seperate out the input m(X) and the target (y)

# %%
X=df[['input']]
y=df[['target']]

# %% [markdown]
# ## Step 3: Explore the given data
#
# Often we will do much more than this, but at least look at things using a scatterplot

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')

ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 4: Fit the model
#
# Fit the linear regression model to the dataset

# %%
lin_reg = LinearRegression().fit(np.sin(X),y) # fit the model

# %% [markdown]
# ## Step 5: Analyze the linear regression model's performance

# %% [markdown]
# Visualize the linear regression model results

# %%
fig = plt.figure() # create a figure
ax = fig.add_subplot() # add a subplot

ax.scatter(X, y, color='red') # plot the actual values
ax.scatter(X,lin_reg.predict(np.sin(X)),color='blue') # plot the predicted values

ax.set_title('Linear Regression') 
ax.set_xlabel('input') 
ax.set_ylabel('target')
plt.tight_layout() # make sure the labels are not cut off
plt.show() # show the plot

# %%
b0 = lin_reg.intercept_[0] # get the intercept
b1 = lin_reg.coef_[0][0] # get the slope
r2 = lin_reg.score(X, y) # get the R^2
print(f"Y = {b0:.2f} + {b1:.2f}sin(x)")
print(f"R^2: {lin_reg.score(np.sin(X), y):.3f}")
# Out:
# Y = 20.13 + 30.59sin(x)
# R^2: 0.953

# %%
df.tail(3)
# Out:
#      input     target
# 497 -22.37  30.930534
# 498 -11.08  52.161367
# 499  -0.18  13.609598

# %% [markdown]
# Changed the sample size to 500 which can be seen from the tail command.

# %% [markdown]
# Here in this model which has sample observations of 500 has a R^2 value of 0.953 which is higher than the original model which has sample observations of 1000 and has a R^2 value of 0.948. From the above finding we can say that, since R^2 = 1-RSS/SSE and we need to find a model with beta1 and beta2 which result in lowest RSS/SSE values, we can clearly say that this model with 500 observations is performing better than the original model.
